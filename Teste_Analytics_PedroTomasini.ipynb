# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroTomasini/Teste_Analytics_PedroTomasini/blob/main/Teste_Analytics_PedroTomasini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Função para gerar dados de vendas
def gerar_dados_vendas(n_registros=100):
    np.random.seed(42)

    data_inicio = datetime(2023, 1, 1)
    data_fim = datetime(2023, 12, 31)

    datas = [data_inicio + timedelta(days=x) for x in range((data_fim - data_inicio).days + 1)]
    datas = np.random.choice(datas, n_registros)

    produtos = ['Laptop', 'Smartphone', 'Tablet', 'Fones', 'Smartwatch', 'TV', 'Console']
    categorias = ['Eletrônicos', 'Acessórios', 'Áudio e Vídeo']

    df = pd.DataFrame({
        'ID': range(1, n_registros + 1),
        'Data': datas,
        'Produto': np.random.choice(produtos, n_registros),
        'Categoria': np.random.choice(categorias, n_registros),
        'Quantidade': np.random.randint(1, 11, n_registros),
        'Preço': np.random.uniform(100, 2000, n_registros).round(2)
    })

    # Adicionar alguns valores nulos e duplicatas para limpeza posterior
    df.loc[np.random.choice(df.index, 5), 'Quantidade'] = np.nan
    df = pd.concat([df, df.sample(5)]).reset_index(drop=True)

    return df

# Gerar dataset
df = gerar_dados_vendas(60)  # Gerando 60 registros para garantir pelo menos 50 após limpeza

# Salvar dataset original
# df.to_csv('vendas_original.csv', index=False)
# print("Dataset original salvo como 'vendas_original.csv'")

# %%
df.head()
# Out:
#    ID       Data     Produto      Categoria  Quantidade    Preço
# 0   1 2023-04-13      Laptop     Acessórios        10.0   857.77
# 1   2 2023-12-15       Fones    Eletrônicos         7.0  1651.22
# 2   3 2023-09-28  Smartphone  Áudio e Vídeo         9.0  1616.86
# 3   4 2023-04-17       Fones    Eletrônicos         7.0   386.36
# 4   5 2023-03-13  Smartphone     Acessórios         1.0  1065.58
